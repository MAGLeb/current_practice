# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('test_data_100k.csv', index_col = 0)
train = pd.read_csv('train_data_200k.csv', index_col = 0)

# %%
train.index = pd.to_datetime(train.index)
train.head()
# Out:
#                          tag1  tag2      tag3  tag4  tag5  tag6      tag7  \
# 2016-08-18 00:00:00  15.78042   NaN       NaN   NaN   NaN   NaN       NaN
# 2016-08-18 00:01:00  15.80157   NaN       NaN   NaN   NaN   NaN  53.06440
# 2016-08-18 00:02:00  15.68913   NaN       NaN   NaN   NaN   NaN       NaN
# 2016-08-18 00:03:00  15.75101   NaN  20.26209   NaN   NaN   NaN  52.95166
# 2016-08-18 00:04:00  15.57773   NaN       NaN   NaN   NaN   NaN       NaN
#
#                      tag8  tag9     tag10  ...     tag74     tag75     tag76  \
# 2016-08-18 00:00:00   NaN   NaN  25.30402  ...  53.02723  66.30531  55.10297
# 2016-08-18 00:01:00   NaN   NaN  25.30464  ...  53.05109  66.30098  55.11534
# 2016-08-18 00:02:00   NaN   NaN  25.30486  ...  53.06495  66.30359  55.09395
# 2016-08-18 00:03:00   NaN   NaN  25.30544  ...  53.06760  66.28421  55.12513
# 2016-08-18 00:04:00   NaN   NaN  25.30540  ...  53.09679  66.26472  55.15526
#
# ...

# %%
train.isnull().sum().plot()
# Out:
# /home/magleb/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %%
train.describe().T
# Out:
#             count       mean       std           min        25%        50%  \
# tag1     199934.0  14.717470  1.873427  2.215690e-08  13.592517  14.940615
# tag2     109370.0   0.003483  0.017229 -5.141738e-03   0.001326   0.003691
# tag3     109456.0  12.696579  4.285856  8.830954e-03   8.111923  14.088605
# tag4         85.0   9.101270  9.667475 -3.354573e+00   4.375712   9.799968
# tag5       9736.0  31.654650  5.039073  1.589887e+01  28.884520  30.903065
# ...           ...        ...       ...           ...        ...        ...
# tag79     48558.0  55.872240  1.450305  4.659067e+01  54.954120  55.834110
# target1  199991.0   0.001156  0.000085  8.257220e-04   0.001101   0.001155
# target2  199991.0   0.049836  0.003685  3.561064e-02   0.047461   0.049773
# target3  199991.0   0.942428  0.003936  9.128610e-01   0.940184   0.942605
# target4  199991.0   0.006580  0.001442  2.595484e-03   0.005565   0.006435
#
#                75%        max
# tag1     15.967078  22.015910
# ...

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(train.corr(), fignum=f.number)
plt.xticks(range(train.select_dtypes(['number']).shape[1]), train.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(train.select_dtypes(['number']).shape[1]), train.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
pd.plotting.scatter_matrix(train.iloc[:, 10 : 15], alpha=0.2)
# Out:
# array([[<AxesSubplot:xlabel='tag11', ylabel='tag11'>,
#         <AxesSubplot:xlabel='tag12', ylabel='tag11'>,
#         <AxesSubplot:xlabel='tag13', ylabel='tag11'>,
#         <AxesSubplot:xlabel='tag14', ylabel='tag11'>,
#         <AxesSubplot:xlabel='tag15', ylabel='tag11'>],
#        [<AxesSubplot:xlabel='tag11', ylabel='tag12'>,
#         <AxesSubplot:xlabel='tag12', ylabel='tag12'>,
#         <AxesSubplot:xlabel='tag13', ylabel='tag12'>,
#         <AxesSubplot:xlabel='tag14', ylabel='tag12'>,
#         <AxesSubplot:xlabel='tag15', ylabel='tag12'>],
#        [<AxesSubplot:xlabel='tag11', ylabel='tag13'>,
#         <AxesSubplot:xlabel='tag12', ylabel='tag13'>,
#         <AxesSubplot:xlabel='tag13', ylabel='tag13'>,
#         <AxesSubplot:xlabel='tag14', ylabel='tag13'>,
#         <AxesSubplot:xlabel='tag15', ylabel='tag13'>],
#        [<AxesSubplot:xlabel='tag11', ylabel='tag14'>,
#         <AxesSubplot:xlabel='tag12', ylabel='tag14'>,
# ...

# %%
figure, axis = plt.subplots(23, 3, figsize=(100, 100))

for i in range(23):
    for j in range(3):
        tag = 1 + i * 3 + j
        axis[i, j].hist(train[f'tag{tag}'], bins=50)

# %%
train[['target1', 'target2', 'target3', 'target4']].corr()
# Out:
#           target1   target2   target3   target4
# target1  1.000000  0.999999 -0.930867 -0.073910
# target2  0.999999  1.000000 -0.930863 -0.073923
# target3 -0.930867 -0.930863  1.000000 -0.295557
# target4 -0.073910 -0.073923 -0.295557  1.000000
